# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
train=pd.read_csv('train-data.csv')

# %%
train.head(5)
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# ...

# %%
train=train.drop(columns=['Unnamed: 0'])

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
train.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
train.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# New_Price            0
# Price                0
# dtype: int64

# %%
num=train.select_dtypes('int').keys()

# %%
num
# Out:
# Index(['Year', 'Kilometers_Driven'], dtype='object')

# %%
#"Mileage","Engine","Power"

# %%
Mileage=train["Mileage"].str.split(" ",n=1,expand=True)

# %%
Mileage.head(5)
# Out:
#         0     1
# 2    18.2  kmpl
# 7   11.36  kmpl
# 10  21.56  kmpl
# 15   13.5  kmpl
# 20  22.69  kmpl

# %%
Mileage.drop(columns=[1],inplace=True)

# %%
Engine=train["Engine"].str.split(" ",n=1,expand=True)

# %%
Engine.drop(columns=[1],inplace=True)

# %%
Power=train["Power"].str.split(" ",n=1,expand=True)

# %%
Power.drop(columns=[1],inplace=True)

# %%
New_Price_encoded=train["New_Price"].str.split(" ",n=1,expand=True)

# %%
train["Power"].shape
# Out:
# (823,)

# %%
Power.shape
# Out:
# (823, 1)

# %%
train["Power"]=Power[0]
train["Mileage"]=Mileage[0]
train["Engine"]=Engine[0]

# %%
train["New_Price"]=New_Price_encoded[0]

# %%
train.head(5)
# Out:
#                                  Name Location  Location_encoded  Year  \
# 2                        Honda Jazz V  Chennai                 2  2011
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai                 9  2016
# 10                   Maruti Ciaz Zeta    Kochi                 7  2018
# 15        Mitsubishi Pajero Sport 4X4    Delhi                 4  2014
# 20                  BMW 3 Series 320d    Kochi                 7  2014
#
#     Kilometers_Driven Fuel_Type  fuel_encoded Transmission  \
# 2               46000    Petrol             2       Manual
# 7               36000    Diesel             1    Automatic
# 10              25692    Petrol             2       Manual
# 15             110000    Diesel             1       Manual
# 20              32982    Diesel             1    Automatic
#
#     Transmission_encoder Owner_Type  Owner_Type_Encoding  Mileage  Engine  \
# 2                      1      First                    0    18.20  1199.0
# ...

# %%
train.select_dtypes("float64")
# Out:
#       Seats   Price
# 2       5.0    4.50
# 7       8.0   17.50
# 10      5.0    9.95
# 15      7.0   15.00
# 20      5.0   18.55
# 28      5.0    9.90
# 34      5.0    6.98
# 36      5.0    8.63
# 44      5.0    8.85
# 47      7.0   10.95
# 60      8.0   16.50
# 67      5.0   35.67
# 69      5.0   10.50
# 73      5.0    6.92
# 81      5.0    4.50
# 102     7.0    3.95
# 106     5.0    3.90
# 110     7.0   19.25
# 111     5.0    3.91
# 113     5.0   20.75
# 117     5.0    6.55
# 119     5.0    7.50
# 122     5.0   10.95
# 133     5.0    2.60
# 134     2.0   54.00
# 135     5.0   11.50
# 148     4.0   37.00
# 149     5.0   26.50
# 173     5.0    6.50
# 182     5.0   33.50
# 187     5.0    7.50
# 193     7.0    8.50
# 200     7.0    6.50
# 201     5.0    9.00
# 210     5.0    3.25
# 219     5.0   26.00
# 223     5.0    3.70
# 225     5.0    2.65
# 228     4.0   35.67
# 235     7.0   19.64
# 237     5.0    3.87
# 256     7.0   18.65
# 261     5.0    2.60
# 264     5.0   61.29
# ...

# %%
train[["Mileage","Engine","Power"]]=train[["Mileage","Engine","Power"]].astype('float64')

# %%
train.head(5)
# Out:
#                                  Name Location  Year  Kilometers_Driven  \
# 2                        Honda Jazz V  Chennai  2011              46000
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 10                   Maruti Ciaz Zeta    Kochi  2018              25692
# 15        Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 20                  BMW 3 Series 320d    Kochi  2014              32982
#
#    Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  \
# 2     Petrol       Manual      First    18.20  1199.0   88.70    5.0
# 7     Diesel    Automatic      First    11.36  2755.0  171.50    8.0
# 10    Petrol       Manual      First    21.56  1462.0  103.25    5.0
# 15    Diesel       Manual      First    13.50  2477.0  175.56    7.0
# 20    Diesel    Automatic      First    22.69  1995.0  190.00    5.0
#
#      New_Price  Price
# 2    8.61 Lakh   4.50
# 7      21 Lakh  17.50
# 10  10.65 Lakh   9.95
# 15  32.01 Lakh  15.00
# ...

# %%
train["Location"].unique()
# Out:
# array(['Chennai', 'Mumbai', 'Kochi', 'Delhi', 'Coimbatore', 'Bangalore',
#        'Pune', 'Ahmedabad', 'Kolkata', 'Hyderabad', 'Jaipur'],
#       dtype=object)

# %%
encoder=LabelEncoder()

# %%
fuel_encoded=encoder.fit_transform(train["Fuel_Type"])

# %%
train.insert(5,"fuel_encoded",fuel_encoded,True)

# %%
Transmission_encoder=encoder.fit_transform(train["Transmission"])

# %%
train.insert(7,"Transmission_encoder",Transmission_encoder,True)

# %%
Owner_Type_Encoding=encoder.fit_transform(train["Owner_Type"])

# %%
train.insert(9,"Owner_Type_Encoding",Owner_Type_Encoding,True)

# %%
Location_encoded=encoder.fit_transform(train["Location"])

# %%
train.insert(2,"Location_encoded",Location_encoded,True)

# %%
train.head(5)
# Out:
#                                  Name Location  Location_encoded  Year  \
# 2                        Honda Jazz V  Chennai                 2  2011
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai                 9  2016
# 10                   Maruti Ciaz Zeta    Kochi                 7  2018
# 15        Mitsubishi Pajero Sport 4X4    Delhi                 4  2014
# 20                  BMW 3 Series 320d    Kochi                 7  2014
#
#     Kilometers_Driven Fuel_Type  fuel_encoded Transmission  \
# 2               46000    Petrol             2       Manual
# 7               36000    Diesel             1    Automatic
# 10              25692    Petrol             2       Manual
# 15             110000    Diesel             1       Manual
# 20              32982    Diesel             1    Automatic
#
#     Transmission_encoder Owner_Type  Owner_Type_Encoding  Mileage  Engine  \
# 2                      1      First                    0    18.20  1199.0
# ...

# %%
train.select_dtypes(["int","float"]).keys()
# Out:
# Index(['Location_encoded', 'Year', 'Kilometers_Driven', 'fuel_encoded',
#        'Transmission_encoder', 'Owner_Type_Encoding', 'Mileage', 'Engine',
#        'Power', 'Seats', 'Price'],
#       dtype='object')

# %%
train.head(5)
# Out:
#                                  Name Location  Location_encoded  Year  \
# 2                        Honda Jazz V  Chennai                 2  2011
# 7   Toyota Innova Crysta 2.8 GX AT 8S   Mumbai                 9  2016
# 10                   Maruti Ciaz Zeta    Kochi                 7  2018
# 15        Mitsubishi Pajero Sport 4X4    Delhi                 4  2014
# 20                  BMW 3 Series 320d    Kochi                 7  2014
#
#     Kilometers_Driven Fuel_Type  fuel_encoded Transmission  \
# 2               46000    Petrol             2       Manual
# 7               36000    Diesel             1    Automatic
# 10              25692    Petrol             2       Manual
# 15             110000    Diesel             1       Manual
# 20              32982    Diesel             1    Automatic
#
#     Transmission_encoder Owner_Type  Owner_Type_Encoding  Mileage  Engine  \
# 2                      1      First                    0    18.20  1199.0
# ...

# %%
#train.to_csv("train_cln.csv")
